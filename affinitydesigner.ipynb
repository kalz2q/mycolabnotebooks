# %% [markdown]
# <a href="https://colab.research.google.com/github/kalz2q/mycolabnotebooks/blob/master/affinitydesigner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # メモ
#
# 1. https://affinity.help/designer/ja.lproj/index.html
# 1. https://affinity.serif.com/ja-jp/tutorials/designer/ipad/
# 1. http://tavmjong.free.fr/INKSCAPE/MANUAL/html/AShortExample.html
#
# affinity designer
# を使っているが、どうもうまく行っていない。
#
# 一通り動画チュートリアルを見たが、多分身についていないのだろう。使おうと思うと思い出せない。
#
# iPad の affinity designer にある help は字が小さくて読む気がしないので読んでいない。 ネット上にあるのはデスクトップ用であるが、iPad 用に読みかえながらこのノートブックにメモを取りながら読んでみよう。

# %% [markdown]
# affinity designer の動画 tutorial をリストしてみる。動画チュートリアルは iPad 用がある。
#
# 1. ジェスチャー
# 1. レイヤースタジオ
# 1. 画像の配置
# 1. 順序付け
# 1. グループ化
# 1. 移動、サイズ変更、回転の操作
# 1. 選択
# 1. クイック書き出し
# 1. 取り消し、やり直し、履歴
# 1. コピー、ペースト、反復複製
# 1. キャンバスのパン、ズーム、回転
# 1. オープンとインポート
# 1. 新規作成と保存
# 1. UIの概要

# %% [markdown]
# # 画面とヘルプ
#
# 起動時の画面の右上に、新規 `+`、ヘルプ `?`、設定 (歯車アイコン)、がある。
#
# このヘルプでテキストベースの膨大なヘルプが出てくる。検索があるので、調べることができる。
#
# このテキストベースのヘルプはオンライン上にはデスクトップ用しかおいていない。オンラインにあるものは各国語に対応しているので、たぶん iPad 用は翻訳が間に合っていないのだろう。
#
# このことも含め、デスクトップ版が正で、iPad 版は機能縮小版みたいなことを書く人がいるが、iPad 版の方がはるかに手軽に使えるので、affnity には頑張って欲しいものだと思う。
#
# ドキュメントビューに入ると右下にヘルプ `?` アイコンがあって、これを押している間、画面上のツールなどのアイコンの名称が出る。
#
# リストアップしてみよう。

# %% [markdown]
# # 画面とアイコン
#
# 上部
# * Home (左矢印) ホーム
# * Document ドキュメント
# * Edit 編集
# * Designer デザイナーペルソナ
# * Pixel ピクセルペルソナ
# * Export 書き出しペルソナ
#
# 左 ツールバー
# * Move 移動ツール
# * Node ノードツール
# * Point Transform ポイント変換ツール
# * Corner コーナーツール
# * Pencil 鉛筆ツール
# * Vector Brush ベクトルブラシツール
# * Pen ペンツール
# * Fill 塗りつぶしツール
# * Transparency 透明性ツール
# * Vector Crop ベクトル切り抜きツール
# * Rectangle 矩形ツール
# * Artistic Text アーティスティックテキストツール
# * Color Picker カラーピッカーツール
#
# 選択関係
# * Deselect 選択解除
# * Snapping スナップ
# * Delete 削除
#
# 右上
# * Hide UI メニューを隠す
#
# 右 スタジオパネル
# * Color カラースタジオ
# * Stroke ストロークスタジオ
# * Brushes ブラシスタジオ
# * Layers レイヤースタジオ
# * Appearance 外観スタジオ
# * Assets アセットスタジオ
# * Stock ストック写真スタジオ
# * Symbols シンボルスタジオ
# * Layer レイヤーエフェクトスタジオ
# * Adjustments 調整スタジオ
# * Text テキストスタジオ
# * Transform 変換スタジオ
# * Navigator ナビゲータースタジオ
# * History 履歴スタジオ

# %% [markdown]
# # Q and A
#
# * グリッドを表示させる。 => 左上のドキュメントアイコン => グリッド => Show Grid
# * グリッドの幅を変える。   => 左上のドキュメントアイコン => グリッド => Spacing => 数値入力
# * グリッドへのスナップをオンにする。 => 左上のドキュメントアイコン => Snapping => Enable Snapping => Snap to grid。画面左下の磁石アイコン(スナッピング)をオンにする。
# * 矩形、円、☆を描く。 => 左のツールからシェイプツールを選ぶ。
# * ドキュメントの解像度 (DPI) => 画面なら 144、印刷物なら 300。

# %% [markdown]
# # アートボード Artboard
#
# アートボードは、同一ドキュメント内の任意の形状およびサイズから成る離散的なデザイン領域のこと。
#
# 同じサイズの2つのアートボードで、ページの両側を表現できる。

# %% [markdown]
# # ライン、カーブ、シェイプについて
#
# ベクトルシェイプやカーブを描画する際には、ペン、鉛筆、ベクトルブラシ、シェイプツールを使用する。カーブやシェイプの編集は、ノードツールを使用して行う。
#
# ### ノードには、次の3つの基本タイプがある。
#
# * シャープ(A)—パスの向きがセグメント間で急激に変化することで、ポイントが作成される。
# * ベジェ(スムーズ)(B)—パスはセグメント間で連続的なカーブを形成する。
# * スマート(C)—パスは連続的なカーブを形成するが、最適にフィットするラインが使用される。
#
#
# ### シェイプ
# シェイプとは、閉じたパスであり、始点や終点の区別ない。シェイプは複数のノードとセグメントで形成される。

# %% [markdown]
# # いまここ

# %% [markdown]
# # ペンツール 鉛筆ツール カーブおよびシェイプを描画する
#
# ベクトルライン、カーブおよびシェイプは、ペンツールまたは鉛筆ツールを使用して簡単に作成できます。ペンツールには、パスの描画方法を変更するモードがいくつかあります。
#
# ペンツール ペンツールで正確なカーブを描画するには:
# [ペンツール]を選択します。
# コンテキストツールバーで、次のモードのいずれかをクリックします。
# ペンモード [ペンモード]—ページ上をクリックしてドラッグすることで、ノードが繰り返し作成されます。ノードごとに表示されるカーブ外のハンドルの位置を変更することで、各ノードの位置決めの際に次のセグメントの形状が決まります。
# スマートモード [スマートモード]—ページ上を繰り返しクリックして各ノードの位置を決定します。コントロールハンドルを調整しなくても、最適にフィットするカーブが作成されます。
# ポリゴンモード [ポリゴンモード]—ページ上を繰り返しクリックして各ノードの位置を決定します。直線セグメントで構成されたシャープなノードによるラインが作成されます。
# 線モード [線モード]—ページ上をクリックしてドラッグすることで、単一セグメントの単純な直線が作成されます。
# 曲線を閉じずに作成を完了するには、を押します。曲線を閉じるには、開始ノードをクリックします。
# [モード]セクションにある別の3つのモードは、上記の4つのモードのいずれか1つと組み合わせて使用できます。
#
# 選択を保持 [新規カーブの作成時に選択を保持]—有効になっている場合、描画中にノードやジオメトリを簡単にスナップできるように、それまでに描画したカーブが選択されたままになります。
# カーブに追加モード [選択されたカーブオブジェクトに新規カーブを追加]—このモードが有効になっている場合、最初のカーブと同じレイヤー上に追加のカーブが作成されます。これにより、多数のカーブレイヤーを管理しやすくなります。たとえば、文字'a'を構成する2つのカーブを単一の'カーブオブジェクト'にすることができます。[レイヤー]>[ジオメトリ]で、各カーブを個別のレイヤーに分離するには[カーブを分離]を、選択されているカーブを1つのレイヤーにまとめるには[カーブを結合]を選択します。
# ラバーバンドモード [ラバーバンドモード]—有効になっている場合、新しいノードの配置前に描画される次のセグメントのプレビューが表示されます。直線セグメントのプレビューでは を同時に押して使用します。
# このツールを使用すると、次のクリックの結果を示す数種類のカーソルが表示される場合があります。
#
# カーソルタイプ	説明
# 	アスタリスク—新しいカーブを作成します
# 	プラス—新しいノードとカーブセグメントを作成します
# 	スロープ—シャープなコーナーに変換するか、ドラッグしてノードを再作成します
# 	円—閉じたシェイプを作成します
# 	円付きアスタリスク—既存のカーブのノードから新しいカーブを作成します。
# 	円付きプラス—既存のカーブのノードとオーバーラップする新しいノードを作成します。
# ノードツール 既存のカーブの作成を続行するには:
#  を押してカーブを編集するか、ノードツールでカーブを選択します。
# 作成を続行するパスの最終ノード上にカーソルを置きます。
# 一度だけクリックすると、そのノードが選択されます。
#  を解除(またはペンツールを選択)し、クリック/ドラッグして必要に応じて新しいノードを配置します。
# 同じカーブ上の既存ノードをクリックまたはドラッグすると、カーブの作成が再開され、オーバーラップする共存ノードが生成されます。代わりに、を押しながらノードをドラッグすると、既存のノードが再描画され、カーブは終了します。
#
# カーブを閉じる カーブを閉じてカスタムシェイプを作成するには:
# 次のいずれかを行います。
#
# [ペン]または[ノードツール]でカーブを選択した状態で、コンテキストツールバーの[カーブを閉じる]をクリックします。
# ペンツールによるカーブの作成時に開始ノードをクリックすると、カーブが最終ノードに結合されてシェイプが作成されます。
#  ストロークに矢印を追加するには:
# ラインまたはカーブを選択し、[ストローク]パネルの[開始]/[終了]ポップアップダイアログから矢印のスタイルを選択します。
# 開始スタイルと終了スタイルの位置として[矢印を線の内側に配置します]か[矢印を線の端に配置します]を選択します。
# 矢印のスタイルを選択し、[開始]スタイルと[終了]スタイルに比率を入力して、選択した矢印とストローク幅との相対的な大きさを調整します。
# ストロークに追加されるサンプルの矢印。
# 点線/破線スタイルについて
# [ストローク]パネルでは、ストロークを点線または破線に変更できます。
#
# パネルの数値グリッドは、2つの数値ペアを使用して線のパターンを設定するものです。
#
# 最初の2つの値は、先頭の点線または破線とそれに続く空白のサイズを設定するものです。
# 第3と第4の値を設定すると、さらに複雑なパターンを導入できます。これらの値は、破線と空白に対して1つおきに別のサイズを設定するものです。
# すべての値が現在のライン幅に基づきます。たとえば、2という値はライン幅の2倍を意味します。
#
#
#
# ラウンド線端が有効で、[破線]の設定がそれぞれ0,1,0,0および0,2,0,0の点線スタイル。
# 点線を作成するには、0,1,0,0、0,2,0,0、0,3,0,0などの設定を使用します。
#
#
#
# バット線端が有効で、[破線]設定がそれぞれ1,2,0,0および1,2,4,2の破線スタイル。
# [フェーズ]の値によって、破線スタイルを前に「シフト」し、スタイルのシーケンス内の別の点からデザインが始まるようにすることができます。これは、閉じたシェイプに対する破線の表示方法に影響を与える場合があります(下記を参照)。
#
#
#
# バット線端が有効で[フェーズ]設定がそれぞれ0および4の破線スタイル1,2,4,2。
# モディファイアーキー
# ペンツールの使用時には、次のモディファイアーキーを使用して描画時のワークフローを短縮できます。
#
# は、[ノード]ツールを一時的に有効にします。
# は、ペンモードでのコントロールハンドルの回転に制約を加えて45°単位にします。スマートモードでは、代わりにノードの配置に制約が加えられます。
# は、強制的にノードを尖点モードにします。
# を押しながらクリックしてドラッグすると、コントロールハンドルの位置に影響を与えずに最後に描画したノードの位置を変更できます。この場合はノードの内外の曲率が維持されます。
# 関連項目:
# シェイプを描画して編集する
# ベクトルラインおよびシェイプを編集する
# ペンツール
# 鉛筆ツール
# ノードツール
# 筆圧感知
# ストロークパネル
