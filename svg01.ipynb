# %% [markdown]
# <a href="https://colab.research.google.com/github/kalz2q/mycolabnotebooks/blob/master/svg01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # メモ
# 1. svg の勉強をする。
# 1. Colab で読まれることを想定している。
# 1. マジックコマンドは %%html を使う。
#
# 参考サイト、とか。
# 1. https://boxy-svg.com/tutorials
# 1. w3scools.com svg tutorial https://www.w3schools.com/graphics/svg_intro.asp
# 1. w3schools SVG examples https://www.w3schools.com/graphics/svg_examples.asp
# 1. learn inkscape https://inkscape.org/learn/
# 1. mdn web docs svg tutorial https://developer.mozilla.org/ja/docs/Web/SVG/Tutorial

# %% [markdown]
# # 概観
# 思うに、SVGのアプローチはいろいろある。
# 1. htmlに画像をテキストで入れる。
# 2. cssやscriptを使っていろいろやる。
# 3. svg を手書きで描く。
# 4. InkscapeやboxySVGなどツールを使って描く。 ツールの使い方を学ぶ。
# 5. アイコンや簡単な画像を作って楽しむ。
# 6. フリーな作品を鑑賞して楽しむ。

# %%
# %%html
# <svg viewBox="0 0 300 300" width="100px" height="100px" xmlns="http://www.w3.org/2000/svg">
#   <defs></defs>
#   <path stroke-width="0" d="M 93.421 209.414 C 89.757 209.614 74.652 212.115 65.433 216.168 C 55.531 220.522 42.073 230.257 36.112 235.467 C 32.46 238.66 31.152 240.607 29.447 243.669 C 27.749 246.72 26.475 249.491 25.894 253.8 C 25.119 259.544 23.049 272.77 26.782 275.995 C 30.749 279.42 42.465 273.019 50.328 272.134 C 58.162 271.254 67.078 272.027 73.874 270.687 C 79.676 269.543 85.071 267.423 88.979 265.379 C 92.041 263.78 94.8 263.237 96.087 260.072 C 97.875 255.683 95.356 246.602 95.199 238.845 C 95.021 230.066 96.487 212.708 95.199 209.896 C 94.758 208.933 94.641 209.348 93.421 209.414 Z" style="stroke-width: 2px; fill: rgb(119, 183, 50);"></path>
#   <path d="M 125.178 27.177 C 136.046 26.36 148.607 32.007 154.909 41.141 C 175.846 71.492 189.2 106.773 203.626 140.896 C 204.748 143.551 200.893 146.097 200.486 148.961 C 198.667 161.83 203.27 176.514 196.993 187.803 C 193.306 194.431 182.711 192.031 175.502 193.886 C 172.739 194.597 168.149 192.775 167.101 195.497 C 160.499 212.642 171.137 243.098 154.207 249.196 C 131.098 257.52 89.143 249.95 84.541 225.234 C 80.093 201.35 122.161 195.695 141.685 181.959 C 143.872 180.42 148.701 182.306 149.313 179.658 C 151.176 171.566 148.827 163.019 147.956 154.755 C 147.735 152.663 147.621 150.106 146.056 148.75 C 143.144 146.23 139.381 144.421 135.59 144.049 C 117.572 142.292 99.251 139.942 81.316 142.438 C 73.099 143.58 66.724 150.538 59.455 154.64 C 57.897 155.52 56.258 156.286 54.837 157.387 C 53.953 158.071 51.995 158.999 52.628 159.932 C 59.244 169.7 66.396 179.293 75.041 187.214 C 78.31 190.211 85.062 187.988 87.4 191.795 C 89.592 195.358 88.812 206.847 85.544 204.298 C 66.816 189.697 48.007 173.259 36.56 152.159 C 33.555 146.617 45.266 143.031 50.408 139.521 C 58.162 134.228 65.718 126.622 75.003 125.919 C 100.889 123.955 129.686 119.355 152.663 131.764 C 167.771 139.923 164.842 164.834 174.206 179.499 C 175.637 181.742 180.015 179.316 181.739 177.302 C 183.435 175.318 182.655 172.093 182.796 169.457 C 183.218 161.603 183.929 153.716 183.428 145.865 C 182.178 126.257 192.78 99.108 177.55 87.227 C 148.956 64.912 109.021 62.095 73.181 59.838 C 64.003 59.261 55.456 70.237 53.216 79.402 C 43.581 118.82 39.661 159.795 38.823 200.427 C 38.49 216.489 36.299 239.111 49.751 247.295 C 86.225 269.486 130.611 274.557 172.424 281.714 C 182.475 283.433 191.984 275.795 201.887 273.334 C 207.877 271.848 215.009 273.501 220.063 269.877 C 225.461 266.006 226.135 257.682 230.618 252.73 C 235.337 247.515 242.205 244.79 247.221 239.878 C 247.947 239.168 247.356 237.711 246.873 236.809 C 245.208 233.702 240.377 231.612 240.912 228.107 C 241.7 222.937 245.713 218.212 250.112 215.579 C 252.056 214.416 254.814 217.108 255.911 219.125 C 259.808 226.305 266.639 234.213 264.535 242.145 C 261.939 251.935 250.289 256.261 243.992 264.074 C 238.922 270.368 237.167 279.79 230.553 284.324 C 223.237 289.342 213.141 294.136 204.948 290.854 C 141.757 265.531 59.539 258.187 21.437 200.525 C -5.668 159.503 37.642 102.695 48.737 54.44 C 49.469 51.253 53.37 49.616 56.381 48.543 C 79.012 40.468 101.285 28.971 125.178 27.177 Z M 56.933 49.478 C 54.011 50.518 50.215 52.1 49.507 55.193 C 38.563 103.177 -4.467 159.664 22.499 200.424 C 60.337 257.616 141.996 264.698 204.711 289.786 C 212.789 293.017 222.758 288.364 229.963 283.411 C 236.504 278.918 238.849 270.066 243.207 263.336 C 249.82 253.123 259.628 244.39 262.873 232.586 C 264.193 227.784 258.257 223.724 255.148 219.891 C 253.854 218.293 250.794 214.769 249.96 216.661 C 247.299 222.692 248.367 229.803 247.861 236.402 C 247.76 237.745 249.062 239.474 248.142 240.43 C 243.234 245.516 236.219 248.151 231.468 253.39 C 226.879 258.449 226.078 266.894 220.555 270.847 C 215.425 274.52 208.197 272.887 202.122 274.401 C 192.189 276.875 182.649 284.525 172.569 282.797 C 130.496 275.585 85.795 270.56 49.121 248.178 C 35.438 239.826 37.46 216.874 37.761 200.52 C 38.517 159.699 42.47 118.514 52.249 78.944 C 54.576 69.525 63.341 58.251 72.779 58.827 C 109.067 61.029 149.485 64.006 178.428 86.604 C 193.863 98.655 183.18 126.166 184.48 146.039 C 184.99 153.862 184.363 161.728 183.856 169.551 C 183.668 172.455 184.281 180.339 182.402 178.157 C 170.566 164.413 168.336 140.464 152.145 132.719 C 128.877 121.589 100.788 123.427 75.353 126.949 C 62.124 128.784 39.315 134.517 41.014 148.124 C 43.96 171.718 68.095 187.07 84.904 203.423 C 87.534 205.985 88.561 195.439 86.5 192.376 C 84.133 188.862 78.038 190.783 74.688 188.248 C 67.868 183.084 62.105 176.499 56.685 169.807 C 54.325 166.894 51.07 163.471 51.583 159.718 C 52.016 156.549 56.216 155.38 58.88 153.719 C 66.044 149.256 72.668 142.555 80.969 141.404 C 99.137 138.879 117.697 141.191 135.942 143.018 C 139.894 143.412 143.815 145.332 146.824 147.993 C 148.532 149.505 148.767 152.267 149.006 154.572 C 149.886 163.116 152.287 172.012 150.16 180.319 C 149.408 183.252 144.155 181.347 141.713 183.053 C 122.516 196.453 81.269 201.964 85.593 225.396 C 90.046 249.516 131.326 256.71 153.74 248.212 C 170.459 241.874 159.576 211.775 166.275 194.804 C 167.471 191.775 172.526 193.574 175.617 192.798 C 182.448 191.084 192.612 193.652 196.03 187.336 C 202.135 176.048 197.646 161.533 199.442 148.751 C 199.844 145.885 203.704 143.341 202.582 140.685 C 188.3 106.928 175.013 72.062 154.295 42.036 C 148.085 33.036 135.715 27.438 125.006 28.255 C 101.359 30.063 79.332 41.485 56.933 49.478 Z M 150.895 216.43 C 156.291 219.406 151.24 231.106 146.201 234.679 C 138.56 240.097 127.886 237.799 118.712 239.248 C 113.048 240.142 107.25 243.13 101.689 241.713 C 99.344 241.115 99.783 236.949 99.978 234.476 C 100.384 229.324 101.532 224.166 103.447 219.386 C 104.372 217.072 105.849 213.911 108.278 213.758 C 122.484 212.874 138.357 209.512 150.895 216.43 Z M 149.135 197.31 C 143.658 193.354 135.266 198.239 129.53 201.788 C 119.07 208.259 109.02 216.316 101.917 226.523 C 99.212 230.41 98.501 238.171 102.35 240.855 C 106.891 244.023 113.185 239.052 118.603 238.159 C 127.647 236.665 136.823 235.855 145.737 233.694 C 147.598 233.242 150.051 232.324 150.506 230.415 C 151.579 225.889 150.024 221.109 149.831 216.455 C 149.568 210.075 154.218 200.982 149.135 197.31 Z M 156.172 10.618 C 166.958 9.8 179.426 15.423 185.68 24.491 C 206.509 54.68 219.829 89.753 234.182 123.693 C 235.304 126.349 231.447 128.893 231.043 131.759 C 229.237 144.584 235.082 160.047 227.589 170.47 C 221.505 178.937 203.378 169.249 197.767 178.053 C 190.972 188.716 199.604 203.599 198.394 216.281 C 198.049 219.9 195.574 223.089 193.215 225.798 C 191.008 228.333 188.277 230.838 185.053 231.605 C 166.767 235.956 147.311 247.011 129.488 240.961 C 118.555 237.25 112.315 219.375 116.146 208.217 C 122.15 190.72 139.373 179.151 154.288 168.697 C 161.757 163.463 175.024 170.024 180.815 162.89 C 186.084 156.4 180.435 145.968 179.56 137.564 C 179.329 135.366 179.157 132.71 177.518 131.275 C 174.559 128.682 170.716 126.818 166.845 126.435 C 148.714 124.644 130.273 122.314 112.221 124.822 C 103.963 125.971 97.394 132.674 90.247 137.081 C 87.688 138.659 83.587 139.689 83.183 142.727 C 82.702 146.348 86.175 149.403 88.206 152.405 C 91.692 157.554 94.729 163.393 99.665 167.083 C 103.945 170.286 111.261 168.138 114.733 172.246 C 117.841 175.922 120.502 184.51 116.302 186.762 C 109.561 190.383 100.946 185.916 93.701 183.537 C 90.592 182.516 87.885 179.868 86.323 176.923 C 79.238 163.569 69.392 150.461 68.115 135.307 C 67.591 129.084 76.703 126.336 81.771 122.886 C 89.499 117.624 96.988 109.459 106.256 109.336 C 134.831 108.957 163.653 113.531 191.175 121.435 C 195.636 122.715 193.257 130.858 195.57 134.984 C 200.649 144.046 205.586 153.636 213.15 160.632 C 215.158 162.488 214.24 155.176 214.404 152.405 C 214.869 144.568 214.149 136.655 215.034 128.854 C 215.415 125.477 217.845 122.56 218.174 119.176 C 219.008 110.507 221.673 101.117 218.485 93.045 C 216.495 88.002 206.711 90.003 204.675 84.98 C 202.699 80.113 210.602 74.85 209.069 69.818 C 206.966 62.91 200.687 57.929 195.098 53.525 C 182.591 43.669 169.221 34.857 155.229 27.394 C 152.349 25.858 148.622 26.166 145.498 27.071 C 131.387 31.163 116.895 34.95 104.059 42.234 C 95.896 46.866 86.096 52.783 83.811 62.075 C 74.105 101.57 70.167 142.648 69.371 183.375 C 69.054 199.581 66.947 222.37 80.514 230.638 C 117.089 252.925 161.633 257.973 203.574 265.156 C 213.641 266.881 223.155 259.199 233.084 256.769 C 238.557 255.431 244.242 255.172 249.723 253.866 C 250.842 253.599 252.038 253.053 252.705 252.092 C 256.243 246.982 257.986 240.571 262.123 235.962 C 266.832 230.713 273.799 228.056 278.76 223.056 C 279.586 222.224 278.33 220.691 278.447 219.508 C 279.118 212.652 278.162 205.206 281.115 199.022 C 282.056 197.052 285.233 200.73 286.609 202.409 C 289.787 206.29 295.776 210.427 294.457 215.314 C 291.222 227.3 281.356 236.232 274.679 246.607 C 270.317 253.387 267.914 262.254 261.337 266.769 C 254.077 271.755 244.045 276.478 235.909 273.221 C 172.956 248.016 91.016 240.805 53.046 183.375 C 26.012 142.487 69.182 85.839 80.203 37.718 C 80.921 34.577 84.769 32.969 87.735 31.912 C 110.253 23.88 132.401 12.419 156.172 10.618 Z" style="fill: rgb(145, 102, 182);"></path>
# </svg>
# Out:
# <svg viewBox="0 0 300 300" width="100px" height="100px" xmlns="http://www.w3.org/2000/svg">
#   <defs></defs>
#   <path stroke-width="0" d="M 93.421 209.414 C 89.757 209.614 74.652 212.115 65.433 216.168 C 55.531 220.522 42.073 230.257 36.112 235.467 C 32.46 238.66 31.152 240.607 29.447 243.669 C 27.749 246.72 26.475 249.491 25.894 253.8 C 25.119 259.544 23.049 272.77 26.782 275.995 C 30.749 279.42 42.465 273.019 50.328 272.134 C 58.162 271.254 67.078 272.027 73.874 270.687 C 79.676 269.543 85.071 267.423 88.979 265.379 C 92.041 263.78 94.8 263.237 96.087 260.072 C 97.875 255.683 95.356 246.602 95.199 238.845 C 95.021 230.066 96.487 212.708 95.199 209.896 C 94.758 208.933 94.641 209.348 93.421 209.414 Z" style="stroke-width: 2px; fill: rgb(119, 183, 50);"></path>
# ...

# %% [markdown]
# # 円 circle

# %% [markdown]
# 円は中心と半径を指定すると描ける。

# %%
# %%html
# <svg width="200" height="200" >
#   <circle cx="100" cy="100" r="80" stroke="green" stroke-width="8" fill="yellow" />
# </svg>
# Out:
# <svg width="200" height="200" >
#   <circle cx="100" cy="100" r="80" stroke="green" stroke-width="8" fill="yellow" />
# </svg>

# %%
# 実験 上記の円をsvgエディターのboxy-svg.comで加工したもの
# viewBoxは全体が見えるように数字を入れた。
# %%html
<svg width="200" height="200" xmlns="http://www.w3.org/2000/svg" viewBox="-10,0,200,200">
  <defs></defs>
  <circle cx="77.474" cy="111.072" r="80" stroke="green" stroke-width="8" fill="yellow"></circle>
  <rect x="23.046" y="99.727" width="105.375" height="64.141" style="fill-rule: evenodd; paint-order: stroke; stroke-miterlimit: 11; stroke: rgb(218, 85, 85); stroke-width: 6px; fill: rgba(255, 255, 246, 0.9);"></rect>
  <circle style="" cx="105.895" cy="70.965" r="17.948"></circle>
  <circle style="" cx="48.244" cy="71.346" r="17.948"></circle>
</svg>
# Out:
# <svg width="200" height="200" xmlns="http://www.w3.org/2000/svg" viewBox="-10,0,200,200">
#   <defs></defs>
#   <circle cx="77.474" cy="111.072" r="80" stroke="green" stroke-width="8" fill="yellow"></circle>
#   <rect x="23.046" y="99.727" width="105.375" height="64.141" style="fill-rule: evenodd; paint-order: stroke; stroke-miterlimit: 11; stroke: rgb(218, 85, 85); stroke-width: 6px; fill: rgba(255, 255, 246, 0.9);"></rect>
#   <circle style="" cx="105.895" cy="70.965" r="17.948"></circle>
#   <circle style="" cx="48.244" cy="71.346" r="17.948"></circle>
# </svg>

# %%
# こちらはboxy-svg.comで作ったもの。widthとheightを加えた。
# viewBoxはboxy-svg.comのもの。
# %%html
<svg width="200" height="200" viewBox="147.221 163.714 132.253 130.422" xmlns="http://www.w3.org/2000/svg">
  <defs></defs>
  <path d="M 172.878 163.103 L 253.513 163.103 C 267.683 163.103 279.17 174.59 279.17 188.76 L 279.17 197.033 C 276.242 194.414 271.887 192.006 266.732 191.951 C 258.758 191.866 241.377 198.675 232.523 203.618 C 224.029 198.004 210.148 193.945 200.147 191.951 C 189.457 189.819 178.879 191.449 168.992 191.951 C 161.486 192.332 154.07 192.413 147.221 193.622 L 147.221 188.76 C 147.221 174.59 158.708 163.103 172.878 163.103 Z M 279.17 269.395 C 279.17 283.565 267.683 295.052 253.513 295.052 L 172.878 295.052 C 158.708 295.052 147.221 283.565 147.221 269.395 L 147.221 225.601 C 147.742 225.346 148.278 225.122 148.833 224.938 C 154.058 223.21 160.27 223.435 167.159 223.105 C 175.246 222.718 186.745 221.938 194.649 223.105 C 201.359 224.096 208.762 225.787 212.059 228.603 C 214.478 230.67 215.612 233.584 215.266 236.392 C 214.851 239.754 210.797 244.667 207.935 247.387 C 205.37 249.827 201.66 250.169 199.23 252.427 C 196.754 254.728 194.012 257.811 193.274 261.132 C 192.497 264.636 193.282 269.888 195.107 273.044 C 196.872 276.097 199.887 279.151 203.812 279.916 C 208.847 280.899 217.701 279.677 223.971 275.335 C 231.862 269.869 242.485 254.119 245.504 245.555 C 247.121 240.966 247.009 237.391 246.354 233.451 C 250.376 231.472 254.658 226.945 259.401 224.938 C 264.978 222.578 273.661 223.454 277.728 220.356 C 278.24 219.966 278.721 219.524 279.17 219.042 Z M 157.996 245.402 C 155.962 247.235 151.863 251.378 151.124 255.023 C 150.354 258.823 151.677 264.693 153.873 267.852 C 155.943 270.829 160.046 273.126 163.494 273.808 C 166.921 274.485 171.51 273.736 174.49 271.975 C 177.463 270.218 180.607 266.938 181.362 263.27 C 182.246 258.976 180.98 250.518 177.697 247.235 C 174.414 243.951 164.964 243.338 161.662 243.57 C 159.768 243.702 159.328 244.203 157.996 245.402 Z" style="fill: rgb(85, 218, 120);"></path>
</svg>
# Out:
# <svg width="200" height="200" viewBox="160 163.714 132.253 130.422" xmlns="http://www.w3.org/2000/svg">
#   <defs></defs>
# ...

# %%
# 実験 数字は x 座標と y 座標が交互に出てくるので、特にツールがなければこのまま使う。
# %%html
<svg width="200" height="200" viewBox="353.085 44.594 256.261 222.663" xmlns="http://www.w3.org/2000/svg">
  <defs></defs>
  <path fill="rgb(255,0,0)" stroke="rgb(255,0,0)" stroke-width="0" d="M 404.483 48.192 C 412.654 46.427 421.845 48.476 430.14 50.025 C 438.332 51.554 446.024 53.767 453.964 57.355 C 462.517 61.22 471.947 67.068 479.621 72.933 C 482.574 75.189 485.673 77.88 488.588 80.603 C 492.099 75.88 495.909 71.423 499.169 68.351 C 506.339 61.596 516.308 57.267 522.993 54.606 C 527.964 52.628 530.512 52.38 535.821 51.857 C 542.862 51.165 555.393 50.067 562.394 51.857 C 568.023 53.297 571.171 54.536 575.681 59.646 C 582.808 67.722 593.849 88.733 597.672 102.713 C 601.096 115.232 601.206 127.095 599.505 139.365 C 597.734 152.137 593.697 163.79 586.676 177.85 C 577.943 195.34 552.718 230.571 547.733 236.036 C 546.383 237.515 546.251 236.77 545.442 237.41 C 544.443 238.201 544.563 239.104 542.235 240.617 C 538.114 243.297 523.662 251.667 512.221 256.748 C 512.046 256.873 511.87 256.994 511.692 257.111 C 509.329 258.666 506.737 260.057 503.068 260.2 C 501.936 260.508 500.93 260.707 500.085 260.776 C 495.529 261.149 492.642 259.551 490.395 257.164 C 478.96 252.502 463.117 243.105 449.383 234.203 C 428.494 220.664 396.144 197.416 382.034 181.515 C 372.085 170.305 368.324 162.29 364.624 150.361 C 360.559 137.257 359.225 117.86 360.042 105.462 C 360.693 95.585 362.958 88.188 366.457 80.721 C 369.885 73.405 374.521 66.378 380.659 61.02 C 387.069 55.426 396.145 49.994 404.483 48.192 Z M 497.947 116.915 C 495.085 118.776 490.573 120.228 486.951 119.664 C 483.084 119.062 478.846 115.675 475.497 112.792 C 472.118 109.883 471.175 106.011 466.793 102.254 C 460.593 96.94 449.047 88.661 439.303 84.845 C 429.779 81.114 416.141 77.974 409.065 79.347 C 404.034 80.322 401.29 83.542 398.527 87.135 C 395.473 91.109 393.491 97.175 392.113 102.713 C 390.686 108.451 389.625 114.018 390.281 121.039 C 391.092 129.723 393.787 142.435 398.527 151.277 C 403.178 159.951 409.016 165.51 418.228 173.727 C 430.75 184.895 456.478 202.589 470.458 211.295 C 480.461 217.526 487.726 221.38 495.198 224.124 C 497.948 225.134 500.863 225.245 503.583 225.379 C 511.896 221.452 521.727 217.489 524.367 215.419 C 525.946 214.181 524.896 214.615 526.2 212.67 C 530.38 206.436 553.126 175.461 560.103 162.273 C 564.874 153.254 566.835 147.709 568.35 140.281 C 569.827 133.044 570.988 126.529 569.267 118.29 C 567.108 107.959 560.11 87.959 553.231 83.012 C 548.236 79.42 541.646 81.282 535.821 83.012 C 529.281 84.954 521.739 90.103 516.121 95.382 C 510.404 100.753 506.808 111.825 501.918 115.083 C 500.662 115.92 499.366 116.487 498.062 116.839 C 498.024 116.865 497.985 116.89 497.947 116.915 Z" style="fill: rgb(166, 209, 48); stroke: rgb(129, 151, 57); stroke-width: 2px;"></path>
</svg>
# Out:
# <svg width="200" height="200" viewBox="353.085 44.594 256.261 222.663" xmlns="http://www.w3.org/2000/svg">
#   <defs></defs>
# ...

# %%
# 実験 circle だけで描く顔
# %%html
<svg width="100" height="100" >
  <circle cx="50" cy="50" r="40" stroke="grey"" stroke-width="4" fill="lightsalmon" />
  <circle cx="30" cy="45" r="10" stroke="white" stroke-width="4" fill="black" />
  <circle cx="70" cy="45" r="10" stroke="white" stroke-width="4" fill="black" />
  <circle cx="50" cy="70" r="10" stroke="white" stroke-width="1" fill="red" />
</svg>
# Out:
# <svg width="100" height="100" >
#   <circle cx="50" cy="50" r="40" stroke="grey"" stroke-width="4" fill="lightsalmon" />
#   <circle cx="30" cy="45" r="10" stroke="white" stroke-width="4" fill="black" />
#   <circle cx="70" cy="45" r="10" stroke="white" stroke-width="4" fill="black" />
#   <circle cx="50" cy="70" r="10" stroke="white" stroke-width="1" fill="red" />
# </svg>

# %%
# 実験 改行なしだと一見コンパクトに書ける
# %%html
<svg width="100" height="100" ><circle cx="50" cy="50" r="40" stroke="blue" stroke-width="4" fill="lightsalmon" /><circle cx="30" cy="45" r="10" stroke="white" stroke-width="4" fill="black" /><circle cx="70" cy="45" r="10" stroke="white" stroke-width="4" fill="black" /><circle cx="50" cy="70" r="10" stroke="white" stroke-width="1" fill="red" /></svg>
# Out:
# <svg width="100" height="100" ><circle cx="50" cy="50" r="40" stroke="blue" stroke-width="4" fill="lightsalmon" /><circle cx="30" cy="45" r="10" stroke="white" stroke-width="4" fill="black" /><circle cx="70" cy="45" r="10" stroke="white" stroke-width="4" fill="black" /><circle cx="50" cy="70" r="10" stroke="white" stroke-width="1" fill="red" /></svg>

# %% [markdown]
# svgには次のようなシェイプがある。
#
# * Rectangle (rect) 四角
# * Circle (circle) 円
# * Ellipse (ellipse) 楕円
# * Line (line) 線
# * Polyline (polyline) 折れ線
# * Polygon (polygon) 多角形
# * Path (path) パス

# %% [markdown]
# # 四角形 rect

# %%
# どのように場所が取れるか実験
# %%html
<style>
    html, body {
        background-color: yellow;
    }
</style>
<br>
<svg width="500" height="200" style="background-color:hotpink;">
  <rect width="300" height="100" style="fill:rgb(0,0,255);stroke-width:20;stroke:rgb(0,0,0)" />
</svg>
# Out:
# <style>
#     html, body {
#         background-color: yellow;
#     }
# </style>
# <br>
# <svg width="500" height="200" style="background-color:hotpink;">
#   <rect width="300" height="100" style="fill:rgb(0,0,255);stroke-width:20;stroke:rgb(0,0,0)" />
# </svg>

# %% [markdown]
# stroke-widthの幅を広くすると、上と左が半分欠ける。
#
# 属性はバラバラにも書ける。名称も同じ。

# %%
# %%html
#
# <svg width="320" height="120">
#   <rect x="10" y="10" width="300" height="100" fill="yellow" stroke-width="20" stroke="blue">
# </svg>
# Out:
# <svg width="320" height="120">
#   <rect x="10" y="10" width="300" height="100" fill="yellow" stroke-width="20" stroke="blue">
# </svg>

# %% [markdown]
# svg の stroke の太さは画像のサイズ内外に半分ずつ幅を取っていることがわかる。
# stroke-width が 20 でも x, y を 10, 10 から描き始めて欠けない

# %%
# colab デフォルトの height を調べよう => svg height="150", shape => 150 - stroke-width
# %%html
<svg>
  <rect width="250" height="140"
  style="fill:green;stroke:red;stroke-width:20;" >
</svg>
<svg>
  <rect width="250" height="150"
  style="fill:green;stroke:red;" >
</svg>
<svg width="250" height="150">
  <rect width="230" height="130" x="10" y = "10"
  style="fill:green;stroke:red;stroke-width:20;" >
</svg>
# Out:
# <svg>
#   <rect width="250" height="140"
#   style="fill:green;stroke:red;stroke-width:20;" >
# </svg>
# <svg>
#   <rect width="250" height="150"
#   style="fill:green;stroke:red;" >
# </svg>
# <svg width="250" height="150">
#   <rect width="230" height="130" x="10" y = "10"
#   style="fill:green;stroke:red;stroke-width:20;" >
# </svg>

# %%
# 不透明度 opacity
# %%html
<!-- <svg width="400" height="180"> -->
<svg>
  <rect x="10" y="10" width="130" height="130"
  style="fill:mediumblue;stroke:pink;stroke-width:20;fill-opacity:0.9;stroke-opacity:0.9" />
</svg>
# Out:
# <!-- <svg width="400" height="180"> -->
# <svg>
#   <rect x="10" y="10" width="130" height="130"
#   style="fill:mediumblue;stroke:pink;stroke-width:20;fill-opacity:0.9;stroke-opacity:0.9" />
# </svg>

# %%
# センタリング
# %%html
<div style="text-align:center">
    <svg width="400" height="180">
        <rect x="50" y="20" width="150" height="150"
            style="fill:blue;stroke:pink;stroke-width:20;fill-opacity:0.1;stroke-opacity:0.9" />
    </svg>
</div>
# Out:
# <div style="text-align:center">
#     <svg width="400" height="180">
#         <rect x="50" y="20" width="150" height="150"
#             style="fill:blue;stroke:pink;stroke-width:20;fill-opacity:0.1;stroke-opacity:0.9" />
#     </svg>
# </div>

# %%
# 角の丸め
# %%html

<svg width="400" height="180">
  <rect x="50" y="20" rx="20" ry="20" width="150" height="150"
  style="fill:red;stroke:black;stroke-width:5;opacity:0.5" />
</svg>
# Out:
# <svg width="400" height="180">
#   <rect x="50" y="20" rx="20" ry="20" width="150" height="150"
#   style="fill:red;stroke:black;stroke-width:5;opacity:0.5" />
# </svg>

# %%
# %%html
#
# <svg width="400" height="180">
#   <rect x="50" y="20" rx="50%" ry="50%" width="150" height="150"
#   style="fill:red;stroke:black;stroke-width:5;opacity:0.5" />
# </svg>
# Out:
# <svg width="400" height="180">
#   <rect x="50" y="20" rx="50%" ry="50%" width="150" height="150"
#   style="fill:red;stroke:black;stroke-width:5;opacity:0.5" />
# </svg>

# %%
# %%html
# <svg height="100" width="100">
#   <circle cx="50" cy="50" r="40" stroke="black" stroke-width="3" fill="red" />
# </svg>
# Out:
# <svg height="100" width="100">
#   <circle cx="50" cy="50" r="40" stroke="black" stroke-width="3" fill="red" />
# </svg>

# %% [markdown]
# # 楕円 ellipse

# %%
# %%html
#
# <svg height="140" width="500">
#   <ellipse cx="200" cy="80" rx="100" ry="50"
#   style="fill:yellow;stroke:purple;stroke-width:2" />
# </svg>
# Out:
# <svg height="140" width="500">
#   <ellipse cx="200" cy="80" rx="100" ry="50"
#   style="fill:yellow;stroke:purple;stroke-width:2" />
# </svg>

# %%
# %%html
#
# <svg height="150" width="500">
#   <ellipse cx="240" cy="100" rx="220" ry="30" style="fill:purple" />
#   <ellipse cx="220" cy="70" rx="190" ry="20" style="fill:lime" />
#   <ellipse cx="210" cy="45" rx="170" ry="15" style="fill:yellow" />
# </svg>
# Out:
# <svg height="150" width="500">
#   <ellipse cx="240" cy="100" rx="220" ry="30" style="fill:purple" />
#   <ellipse cx="220" cy="70" rx="190" ry="20" style="fill:lime" />
#   <ellipse cx="210" cy="45" rx="170" ry="15" style="fill:yellow" />
# </svg>

# %% [markdown]
# 後に描いた図形が上にくる。

# %%
# %%html
#
# <svg height="100" width="500">
#   <ellipse cx="240" cy="50" rx="220" ry="30" style="fill:yellow" />
#   <ellipse cx="220" cy="50" rx="190" ry="20" style="fill:white" />
# </svg>
# Out:
# <svg height="100" width="500">
#   <ellipse cx="240" cy="50" rx="220" ry="30" style="fill:yellow" />
#   <ellipse cx="220" cy="50" rx="190" ry="20" style="fill:white" />
# </svg>

# %% [markdown]
# # 線 line

# %%
# %%html
#
# <svg height="210" width="500">
#   <line x1="0" y1="0" x2="200" y2="200" style="stroke:rgb(255,0,0);stroke-width:2" />
# </svg>
# Out:
# <svg height="210" width="500">
#   <line x1="0" y1="0" x2="200" y2="200" style="stroke:rgb(255,0,0);stroke-width:2" />
# </svg>

# %% [markdown]
# # 多角形 polygon

# %%
# %%html
#
# <svg height="210" width="500">
#   <polygon points="200,10 250,190 160,210" style="fill:lime;stroke:purple;stroke-width:1" />
# </svg>
# Out:
# <svg height="210" width="500">
#   <polygon points="200,10 250,190 160,210" style="fill:lime;stroke:purple;stroke-width:1" />
# </svg>

# %%
# %%html
# <svg height="250" width="500">
#   <polygon points="220,10 300,210 170,250 123,234" style="fill:lime;stroke:purple;stroke-width:1" />
# </svg>
# Out:
# <svg height="250" width="500">
#   <polygon points="220,10 300,210 170,250 123,234" style="fill:lime;stroke:purple;stroke-width:1" />
# </svg>

# %%
# %%html
# <svg height="210" width="500">
#   <polygon points="100,10 40,198 190,78 10,78 160,198"
#   style="fill:lime;stroke:purple;stroke-width:5;fill-rule:nonzero;" />
# </svg>
# Out:
# <svg height="210" width="500">
#   <polygon points="100,10 40,198 190,78 10,78 160,198"
#   style="fill:lime;stroke:purple;stroke-width:5;fill-rule:nonzero;" />
# </svg>

# %%
# %%html
# <svg height="210" width="500">
#   <polygon points="100,10 40,198 190,78 10,78 160,198"
#   style="fill:lime;stroke:purple;stroke-width:5;fill-rule:evenodd;" />
# </svg>
# Out:
# <svg height="210" width="500">
#   <polygon points="100,10 40,198 190,78 10,78 160,198"
#   style="fill:lime;stroke:purple;stroke-width:5;fill-rule:evenodd;" />
# </svg>

# %% [markdown]
# # 折れ線 polyline

# %%
# %%html
#
# <svg height="200" width="500">
#   <polyline points="20,20 40,25 60,40 80,120 120,140 200,180"
#   style="fill:none;stroke:white;stroke-width:3" />
# </svg>
# Out:
# <svg height="200" width="500">
#   <polyline points="20,20 40,25 60,40 80,120 120,140 200,180"
#   style="fill:none;stroke:white;stroke-width:3" />
# </svg>

# %%
# %%html
#
# <svg height="180" width="500">
#   <polyline points="0,40 40,40 40,80 80,80 80,120 120,120 120,160"
#   style="fill:None;stroke:red;stroke-width:4" />
# </svg>
# Out:
# <svg height="180" width="500">
#   <polyline points="0,40 40,40 40,80 80,80 80,120 120,120 120,160"
#   style="fill:None;stroke:red;stroke-width:4" />
# </svg>

# %% [markdown]
# # パス path
#
# パスにはつぎのコマンドがある。
#
# * M = moveto
# * L = lineto
# * H = horizontal lineto
# * V = vertical lineto
# * C = curveto
# * S = smooth curveto
# * Q = quadratic Bézier curve
# * T = smooth quadratic Bézier curveto
# * A = elliptical Arc
# * Z = closepath
#
# 大文字だと絶対座標、小文字だと相対座標。

# %%
# %%html
#
# <svg height="210" width="400">
#   <path d="M150 0 L75 200 L225 200 Z" style="fill:cyan;" />
# </svg>
# Out:
# <svg height="210" width="400">
#   <path d="M150 0 L75 200 L225 200 Z" style="fill:cyan;" />
# </svg>

# %% [markdown]
# # ベジェ曲線
#
# 次の例では、2次ベジェ曲線を作成する。。AとCは開始点と終了点、Bは制御点。

# %%
# %%html
#
# <svg height="400" width="450">
#   <path id="lineAB" d="M 100 350 l 150 -300" stroke="red"
#   stroke-width="3" fill="none" />
#   <path id="lineBC" d="M 250 50 l 150 300" stroke="red"
#   stroke-width="3" fill="none" />
#   <path d="M 175 200 l 150 0" stroke="green" stroke-width="3"
#   fill="none" />
#   <path d="M 100 350 q 150 -300 300 0" stroke="blue"
#   stroke-width="5" fill="none" />
#   <!-- Mark relevant points -->
#   <g stroke="black" stroke-width="3" fill="black">
#     <circle id="pointA" cx="100" cy="350" r="3" />
#     <circle id="pointB" cx="250" cy="50" r="3" />
#     <circle id="pointC" cx="400" cy="350" r="3" />
#   </g>
#   <!-- Label the points -->
#   <g font-size="30" font-family="sans-serif" fill="black" stroke="none"
#   text-anchor="middle">
#     <text x="100" y="350" dx="-30">A</text>
#     <text x="250" y="50" dy="-10">B</text>
#     <text x="400" y="350" dx="30">C</text>
#   </g>
# </svg>
# Out:
# <svg height="400" width="450">
#   <path id="lineAB" d="M 100 350 l 150 -300" stroke="red"
#   stroke-width="3" fill="none" />
#   <path id="lineBC" d="M 250 50 l 150 300" stroke="red"
#   stroke-width="3" fill="none" />
#   <path d="M 175 200 l 150 0" stroke="green" stroke-width="3"
#   fill="none" />
#   <path d="M 100 350 q 150 -300 300 0" stroke="blue"
#   stroke-width="5" fill="none" />
#   <!-- Mark relevant points -->
#   <g stroke="black" stroke-width="3" fill="black">
#     <circle id="pointA" cx="100" cy="350" r="3" />
#     <circle id="pointB" cx="250" cy="50" r="3" />
#     <circle id="pointC" cx="400" cy="350" r="3" />
#   </g>
#   <!-- Label the points -->
#   <g font-size="30" font-family="sans-serif" fill="black" stroke="none"
#   text-anchor="middle">
#     <text x="100" y="350" dx="-30">A</text>
#     <text x="250" y="50" dy="-10">B</text>
#     <text x="400" y="350" dx="30">C</text>
#   </g>
# </svg>

# %% [markdown]
# # テキスト

# %%
# %%html
#
# <svg height="30" width="200">
#   <text x="0" y="15" fill="red">I love SVG!</text>
# </svg>
# Out:
# <svg height="30" width="200">
#   <text x="0" y="15" fill="red">I love SVG!</text>
# </svg>

# %%
# %%html
#
# <svg height="60" width="200">
#   <text x="0" y="15" fill="red" transform="rotate(30 20,40)">I love SVG</text>
# </svg>
# Out:
# <svg height="60" width="200">
#   <text x="0" y="15" fill="red" transform="rotate(30 20,40)">I love SVG</text>
# </svg>

# %%
# %%html
#
# <svg height="90" width="200">
#   <text x="10" y="20" style="fill:red;">Several lines:
#     <tspan x="10" y="45">First line.</tspan>
#     <tspan x="10" y="70">Second line.</tspan>
#   </text>
# </svg>
# Out:
# <svg height="90" width="200">
#   <text x="10" y="20" style="fill:red;">Several lines:
#     <tspan x="10" y="45">First line.</tspan>
#     <tspan x="10" y="70">Second line.</tspan>
#   </text>
# </svg>

# %%
# %%html
#
# <svg height="30" width="200" xmlns:xlink="http://www.w3.org/1999/xlink">
#   <a xlink:href="https://www.w3schools.com/graphics/" target="_blank">
#     <text x="0" y="15" fill="red">I love SVG!</text>
#   </a>
# </svg>
# Out:
# <svg height="30" width="200" xmlns:xlink="http://www.w3.org/1999/xlink">
#   <a xlink:href="https://www.w3schools.com/graphics/" target="_blank">
#     <text x="0" y="15" fill="red">I love SVG!</text>
#   </a>
# </svg>

# %% [markdown]
# # ストローク
#
# * ストロークとは
# * ストローク幅
# * ストロークラインキャップ
# * ストロークダッシュ

# %%
# %%html
#
# <svg height="80" width="300">
#   <g fill="none">
#     <path stroke="red" d="M5 20 l215 0" />
#     <path stroke="black" d="M5 40 l215 0" />
#     <path stroke="blue" d="M5 60 l215 0" />
#   </g>
# </svg>
# Out:
# <svg height="80" width="300">
#   <g fill="none">
#     <path stroke="red" d="M5 20 l215 0" />
#     <path stroke="black" d="M5 40 l215 0" />
#     <path stroke="blue" d="M5 60 l215 0" />
#   </g>
# </svg>

# %% [markdown]
# ストロークは線、テキスト、図形など要素のアウトラインのことで、その太さは`stroke-width`で指定する。

# %%
# %%html
#
# <svg height="80" width="300">
#   <g fill="none" stroke="black">
#     <path stroke-width="2" d="M5 20 l215 0" />
#     <path stroke-width="4" d="M5 40 l215 0" />
#     <path stroke-width="6" d="M5 60 l215 0" />
#   </g>
# </svg>
# Out:
# <svg height="80" width="300">
#   <g fill="none" stroke="black">
#     <path stroke-width="2" d="M5 20 l215 0" />
#     <path stroke-width="4" d="M5 40 l215 0" />
#     <path stroke-width="6" d="M5 60 l215 0" />
#   </g>
# </svg>

# %% [markdown]
# `stroke-linecap` は線の端のタイプを指定する。
#
# (矢印はない)

# %%
# %%html
# <svg height="80" width="300">
#   <g fill="none" stroke="black" stroke-width="6">
#     <path stroke-linecap="butt" d="M5 20 l215 0" />
#     <path stroke-linecap="round" d="M5 40 l215 0" />
#     <path stroke-linecap="square" d="M5 60 l215 0" />
#   </g>
# </svg>
# Out:
# <svg height="80" width="300">
#   <g fill="none" stroke="black" stroke-width="6">
#     <path stroke-linecap="butt" d="M5 20 l215 0" />
#     <path stroke-linecap="round" d="M5 40 l215 0" />
#     <path stroke-linecap="square" d="M5 60 l215 0" />
#   </g>
# </svg>

# %% [markdown]
# `stroke-dasharray` 点線を作るのに使われる。

# %%
# %%html
#
# <svg height="80" width="300">
#   <g fill="none" stroke="black" stroke-width="4">
#     <path stroke-dasharray="5,5" d="M5 20 l215 0" />
#     <path stroke-dasharray="10,10" d="M5 40 l215 0" />
#     <path stroke-dasharray="20,10,5,5,5,10" d="M5 60 l215 0" />
#   </g>
# </svg>
# Out:
# <svg height="80" width="300">
#   <g fill="none" stroke="black" stroke-width="4">
#     <path stroke-dasharray="5,5" d="M5 20 l215 0" />
#     <path stroke-dasharray="10,10" d="M5 40 l215 0" />
#     <path stroke-dasharray="20,10,5,5,5,10" d="M5 60 l215 0" />
#   </g>
# </svg>

# %% [markdown]
# # SVG フィルター
#
# SVG フィルターは SVG 図形に特殊効果を与える。
#
# フィルター要素には次のようなものがある。
#
# * (feBlend) - 図形を結合するフィルター
# * (feColorMatrix) - 色変化のフィルター
# * (feComponentTransfer)
# * (feComposite)
# * (feConvolveMatrix)
# * (feDiffuseLighting)
# * (feDisplacementMap)
# * (feFlood)
# * (feGaussianBlur) - ガウスぼかし
# * (feImage)
# * (feMerge)
# * (feMorphology)
# * (feOffset) - ドロップ・シャドーのフィルター
# * (feSpecularLighting)
# * (feTile)
# * (feTurbulence)
# * (feDistantLight) - 遠い光源のフィルター
# * (fePointLight) - 点光源のフィルター
# * (feSpotLight) - スポット光源のフィルター
#
# SVG 要素に同時に複数のフィルターが使える!!!!
#
# SVGフィルターは `<defs>` 要素内で定義される。
# `<filter>` 要素は、SVGフィルターを定義するために使用される。 `<filter>` 要素は、フィルターを識別する id 属性を付け、グラフィックでは使用するフィルターを指定する。

# %% [markdown]
# ### ガウスぼかし

# %%
# %%html
#
# <svg height="110" width="110">
#   <defs>
#     <filter id="f1" x="0" y="0">
#       <feGaussianBlur in="SourceGraphic" stdDeviation="15" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f1)" />
# </svg>
# Out:
# <svg height="110" width="110">
#   <defs>
#     <filter id="f1" x="0" y="0">
#       <feGaussianBlur in="SourceGraphic" stdDeviation="15" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f1)" />
# </svg>

# %% [markdown]
# # ドロップシャドー

# %%
# %%html
#
# <svg height="120" width="120">
#   <defs>
#     <filter id="f1" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceGraphic" dx="20" dy="20" />
#       <feBlend in="SourceGraphic" in2="offOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f1)" />
# </svg>
# Out:
# <svg height="120" width="120">
#   <defs>
#     <filter id="f1" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceGraphic" dx="20" dy="20" />
#       <feBlend in="SourceGraphic" in2="offOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f1)" />
# </svg>

# %%
# %%html
#
# <svg height="140" width="140">
#   <defs>
#     <filter id="f2" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceGraphic" dx="20" dy="20" />
#       <feGaussianBlur result="blurOut" in="offOut" stdDeviation="10" />
#       <feBlend in="SourceGraphic" in2="blurOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f2)" />
# </svg>
# Out:
# <svg height="140" width="140">
#   <defs>
#     <filter id="f2" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceGraphic" dx="20" dy="20" />
#       <feGaussianBlur result="blurOut" in="offOut" stdDeviation="10" />
#       <feBlend in="SourceGraphic" in2="blurOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f2)" />
# </svg>

# %%
# %%html
#
# <svg height="140" width="140">
#   <defs>
#     <filter id="f3" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceAlpha" dx="20" dy="20" />
#       <feGaussianBlur result="blurOut" in="offOut" stdDeviation="10" />
#       <feBlend in="SourceGraphic" in2="blurOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f3)" />
# </svg>
# Out:
# <svg height="140" width="140">
#   <defs>
#     <filter id="f3" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceAlpha" dx="20" dy="20" />
#       <feGaussianBlur result="blurOut" in="offOut" stdDeviation="10" />
#       <feBlend in="SourceGraphic" in2="blurOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f3)" />
# </svg>

# %%
# %%html
#
# <svg height="140" width="140">
#   <defs>
#     <filter id="f4" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceGraphic" dx="20" dy="20" />
#       <feColorMatrix result="matrixOut" in="offOut" type="matrix"
#       values="0.2 0 0 0 0 0 0.2 0 0 0 0 0 0.2 0 0 0 0 0 1 0" />
#       <feGaussianBlur result="blurOut" in="matrixOut" stdDeviation="10" />
#       <feBlend in="SourceGraphic" in2="blurOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f4)" />
# </svg>
# Out:
# <svg height="140" width="140">
#   <defs>
#     <filter id="f4" x="0" y="0" width="200%" height="200%">
#       <feOffset result="offOut" in="SourceGraphic" dx="20" dy="20" />
#       <feColorMatrix result="matrixOut" in="offOut" type="matrix"
#       values="0.2 0 0 0 0 0 0.2 0 0 0 0 0 0.2 0 0 0 0 0 1 0" />
#       <feGaussianBlur result="blurOut" in="matrixOut" stdDeviation="10" />
#       <feBlend in="SourceGraphic" in2="blurOut" mode="normal" />
#     </filter>
#   </defs>
#   <rect width="90" height="90" stroke="green" stroke-width="3"
#   fill="yellow" filter="url(#f4)" />
# </svg>

# %% [markdown]
# # グラデーション
#
# グラデーションは2種類ある。
#
# * リニア
# * ラディアル (放射状)

# %%
# %%html
# <svg height="150" width="400">
#   <defs>
#     <linearGradient id="grad1" x1="0%" y1="0%" x2="100%" y2="0%">
#       <stop offset="0%" style="stop-color:rgb(255,255,0);stop-opacity:1" />
#       <stop offset="100%" style="stop-color:rgb(255,0,0);stop-opacity:1" />
#     </linearGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad1)" />
# </svg>
# Out:
# <svg height="150" width="400">
#   <defs>
#     <linearGradient id="grad1" x1="0%" y1="0%" x2="100%" y2="0%">
#       <stop offset="0%" style="stop-color:rgb(255,255,0);stop-opacity:1" />
#       <stop offset="100%" style="stop-color:rgb(255,0,0);stop-opacity:1" />
#     </linearGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad1)" />
# </svg>

# %%
# %%html
#
# <svg height="150" width="400">
#   <defs>
#     <linearGradient id="grad2" x1="0%" y1="0%" x2="0%" y2="100%">
#       <stop offset="0%" style="stop-color:rgb(255,0,0);stop-opacity:1" />
#       <stop offset="100%" style="stop-color:rgb(255,255,0);stop-opacity:1" />
#     </linearGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad2)" />
# </svg>
# Out:
# <svg height="150" width="400">
#   <defs>
#     <linearGradient id="grad2" x1="0%" y1="0%" x2="0%" y2="100%">
#       <stop offset="0%" style="stop-color:rgb(255,0,0);stop-opacity:1" />
#       <stop offset="100%" style="stop-color:rgb(255,255,0);stop-opacity:1" />
#     </linearGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad2)" />
# </svg>

# %%
# %%html
#
# <svg height="150" width="400">
#   <defs>
#     <linearGradient id="grad3" x1="0%" y1="0%" x2="100%" y2="0%">
#       <stop offset="0%" style="stop-color:rgb(255,255,0);stop-opacity:1" />
#       <stop offset="100%" style="stop-color:rgb(255,0,0);stop-opacity:1" />
#     </linearGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad3)" />
#   <text fill="#ffffff" font-size="45" font-family="Verdana" x="150" y="86">
#   SVG</text>
# </svg>
# Out:
# <svg height="150" width="400">
#   <defs>
#     <linearGradient id="grad3" x1="0%" y1="0%" x2="100%" y2="0%">
#       <stop offset="0%" style="stop-color:rgb(255,255,0);stop-opacity:1" />
#       <stop offset="100%" style="stop-color:rgb(255,0,0);stop-opacity:1" />
#     </linearGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad3)" />
#   <text fill="#ffffff" font-size="45" font-family="Verdana" x="150" y="86">
#   SVG</text>
# </svg>

# %%
# %%html
#
# <svg height="150" width="500">
#   <defs>
#     <radialGradient id="grad1" cx="50%" cy="50%" r="50%" fx="50%" fy="50%">
#       <stop offset="0%" style="stop-color:rgb(255,255,255);
#       stop-opacity:0" />
#       <stop offset="100%" style="stop-color:rgb(0,0,255);stop-opacity:1" />
#     </radialGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad1)" />
# </svg>
# Out:
# <svg height="150" width="500">
#   <defs>
#     <radialGradient id="grad1" cx="50%" cy="50%" r="50%" fx="50%" fy="50%">
#       <stop offset="0%" style="stop-color:rgb(255,255,255);
#       stop-opacity:0" />
#       <stop offset="100%" style="stop-color:rgb(0,0,255);stop-opacity:1" />
#     </radialGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad1)" />
# </svg>

# %%
# %%html
#
# <svg height="150" width="500">
#   <defs>
#     <radialGradient id="grad2" cx="20%" cy="30%" r="30%" fx="50%" fy="50%">
#       <stop offset="0%" style="stop-color:rgb(255,255,255);
#       stop-opacity:0" />
#       <stop offset="100%" style="stop-color:rgb(0,0,255);stop-opacity:1" />
#     </radialGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad2)" />
# </svg>
# Out:
# <svg height="150" width="500">
#   <defs>
#     <radialGradient id="grad2" cx="20%" cy="30%" r="30%" fx="50%" fy="50%">
#       <stop offset="0%" style="stop-color:rgb(255,255,255);
#       stop-opacity:0" />
#       <stop offset="100%" style="stop-color:rgb(0,0,255);stop-opacity:1" />
#     </radialGradient>
#   </defs>
#   <ellipse cx="200" cy="70" rx="85" ry="55" fill="url(#grad2)" />
# </svg>

# %% [markdown]
# # w3schools SVG examples
#
# https://www.w3schools.com/graphics/svg_examples.asp

# %% [markdown]
# Rectangle that repeatedly fade away over 5 seconds

# %%
# %%html
#
# <svg width="400" height="400">
#   <rect x="20" y="20" width="250" height="250" style="fill:blue">
#     <animate attributeType="CSS" attributeName="opacity" from="1" to="0" dur="5s" repeatCount="indefinite" />
#   </rect>
# </svg>

# %% [markdown]
# A growing rectangle that will change color

# %%
# %%html
#
# <svg width="500" height="500">
#   <rect id="rec" x="300" y="100" width="300" height="100" style="fill:lime">
#     <animate attributeName="x" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="0" />
#     <animate attributeName="y" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="0" />
#     <animate attributeName="width" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="800" />
#     <animate attributeName="height" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="300" />
#     <animate attributeName="fill" attributeType="CSS" from="lime" to="red" begin="2s" dur="4s" fill="freeze" />
#   </rect>
#   Sorry, your browser does not support inline SVG.
# </svg>
# Out:
# <svg width="500" height="500">
#   <rect id="rec" x="300" y="100" width="300" height="100" style="fill:lime">
#     <animate attributeName="x" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="0" />
#     <animate attributeName="y" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="0" />
#     <animate attributeName="width" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="800" />
#     <animate attributeName="height" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="300" />
#     <animate attributeName="fill" attributeType="CSS" from="lime" to="red" begin="2s" dur="4s" fill="freeze" />
#   </rect>
#   Sorry, your browser does not support inline SVG.
# </svg>

# %% [markdown]
# Three rectangles that will change color

# %%
# %%html
#
# <svg width="500" height="500">
#   <rect x="10" y="20" width="90" height="60">
#     <animate id="a1" attributeName="fill" from="red" to="blue" dur="3s" fill="freeze" />
#   </rect>
#   <rect x="10" y="120" width="90" height="60">
#     <animate id="a2" attributeName="fill" from="blue" to="yellow" begin="a1.end" dur="3s" fill="freeze" />
#   </rect>
#   <rect x="10" y="220" width="90" height="60">
#     <animate id="a3" attributeName="fill" from="yellow" to="green" begin="a2.end" dur="3s" fill="freeze" />
#   </rect>
#   Sorry, your browser does not support inline SVG.
# </svg>
# Out:
# <svg width="500" height="500">
#   <rect x="10" y="20" width="90" height="60">
#     <animate id="a1" attributeName="fill" from="red" to="blue" dur="3s" fill="freeze" />
#   </rect>
#   <rect x="10" y="120" width="90" height="60">
#     <animate id="a2" attributeName="fill" from="blue" to="yellow" begin="a1.end" dur="3s" fill="freeze" />
#   </rect>
#   <rect x="10" y="220" width="90" height="60">
#     <animate id="a3" attributeName="fill" from="yellow" to="green" begin="a2.end" dur="3s" fill="freeze" />
#   </rect>
#   Sorry, your browser does not support inline SVG.
# </svg>

# %% [markdown]
# Move text along a motion path

# %%
# %%html
#
# <svg width="500" height="500">
#   <g transform="translate(100,100)">
#     <text id="TextElement" x="0" y="0" style="font-family:Verdana;font-size:24"> It's SVG!
#       <animateMotion path="M 0 0 L 100 100" dur="5s" fill="freeze" />
#     </text>
#   </g>
#   Sorry, your browser does not support inline SVG.
# </svg>
# Out:
# <svg width="500" height="500">
#   <g transform="translate(100,100)">
#     <text id="TextElement" x="0" y="0" style="font-family:Verdana;font-size:24"> It's SVG!
#       <animateMotion path="M 0 0 L 100 100" dur="5s" fill="freeze" />
#     </text>
#   </g>
#   Sorry, your browser does not support inline SVG.
# </svg>

# %% [markdown]
# Move, rotate, and scale text along a motion path

# %%
# %%html
#
# <svg width="600" height="600">
#   <g transform="translate(100,100)">
#     <text id="TextElement" x="0" y="0" style="font-family:Verdana;font-size:24; visibility:hidden"> It's SVG!
#       <set attributeName="visibility" attributeType="CSS" to="visible" begin="1s" dur="5s" fill="freeze" />
#       <animateMotion path="M 0 0 L 100 100" begin="1s" dur="5s" fill="freeze" />
#       <animateTransform attributeName="transform" attributeType="XML" type="rotate" from="-30" to="0" begin="1s" dur="5s" fill="freeze" />
#       <animateTransform attributeName="transform" attributeType="XML" type="scale" from="1" to="3" additive="sum" begin="1s" dur="5s" fill="freeze" />
#     </text>
#   </g>
#   Sorry, your browser does not support inline SVG.
# </svg>
# Out:
# <svg width="600" height="600">
#   <g transform="translate(100,100)">
#     <text id="TextElement" x="0" y="0" style="font-family:Verdana;font-size:24; visibility:hidden"> It's SVG!
#       <set attributeName="visibility" attributeType="CSS" to="visible" begin="1s" dur="5s" fill="freeze" />
#       <animateMotion path="M 0 0 L 100 100" begin="1s" dur="5s" fill="freeze" />
#       <animateTransform attributeName="transform" attributeType="XML" type="rotate" from="-30" to="0" begin="1s" dur="5s" fill="freeze" />
#       <animateTransform attributeName="transform" attributeType="XML" type="scale" from="1" to="3" additive="sum" begin="1s" dur="5s" fill="freeze" />
#     </text>
#   </g>
#   Sorry, your browser does not support inline SVG.
# </svg>

# %% [markdown]
# Move, rotate, and scale text along a motion path + a growing rectangle that will change color
# Rotating ellipses

# %%
# %%html
#
# <svg width="600" height="600">
#   <rect id="rec" x="300" y="100" width="300" height="100" style="fill:lime">
#     <animate attributeName="x" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="0" />
#     <animate attributeName="y" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="0" />
#     <animate attributeName="width" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="800" />
#     <animate attributeName="height" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="300" />
#     <animate attributeName="fill" attributeType="CSS" from="lime" to="red" begin="2s" dur="4s" fill="freeze" />
#   </rect>
#   <g transform="translate(100,100)">
#     <text id="TextElement" x="0" y="0" style="font-family:Verdana;font-size:24; visibility:hidden"> It's SVG!
#       <set attributeName="visibility" attributeType="CSS" to="visible" begin="1s" dur="5s" fill="freeze" />
#       <animateMotion path="M 0 0 L 100 100" begin="1s" dur="5s" fill="freeze" />
#       <animate attributeName="fill" attributeType="CSS" from="red" to="blue" begin="1s" dur="5s" fill="freeze" />
#       <animateTransform attributeName="transform" attributeType="XML" type="rotate" from="-30" to="0" begin="1s" dur="5s" fill="freeze" />
#       <animateTransform attributeName="transform" attributeType="XML" type="scale" from="1" to="3" additive="sum" begin="1s" dur="5s" fill="freeze" />
#     </text>
#   </g>
# </svg>
# Out:
# <svg width="600" height="600">
#   <rect id="rec" x="300" y="100" width="300" height="100" style="fill:lime">
#     <animate attributeName="x" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="0" />
#     <animate attributeName="y" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="0" />
#     <animate attributeName="width" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="300" to="800" />
#     <animate attributeName="height" attributeType="XML" begin="0s" dur="6s" fill="freeze" from="100" to="300" />
#     <animate attributeName="fill" attributeType="CSS" from="lime" to="red" begin="2s" dur="4s" fill="freeze" />
#   </rect>
#   <g transform="translate(100,100)">
#     <text id="TextElement" x="0" y="0" style="font-family:Verdana;font-size:24; visibility:hidden"> It's SVG!
#       <set attributeName="visibility" attributeType="CSS" to="visible" begin="1s" dur="5s" fill="freeze" />
# ...

# %% [markdown]
# # background-image
# で inline で svg を入れるやりかた。

# %%
# urlにsvgコードを組み込む
# %%html
<style>
    .box {
        width: 600px;
        height: 200px;
        background-image:
            /* url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='40' height='40'><circle cx='50' cy='50' r='40' stroke='black' stroke-width='3' fill='red'/></svg>"); */
            url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='40' height='40'><circle cx='50' cy='50' r='40' stroke='black' stroke-width='3' fill='red'/></svg>");
    }
</style>
<div class="container">
    <div class="box">BOX</div>
</div>
# Out:
# <style>
#     .box {
#         width: 600px;
#         height: 200px;
#         background-image:
#             /* url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='40' height='40'><circle cx='50' cy='50' r='40' stroke='black' stroke-width='3' fill='red'/></svg>"); */
#             url("data:image/svg+xml;utf8,<svg width='40' height='40'><circle cx='50' cy='50' r='40' stroke='black' stroke-width='3' fill='red'/></svg>");
#     }
# </style>
# <div class="container">
#     <div class="box">BOX</div>
# </div>

# %%
# %%html
# <style>
#     .box {
#         width: 600px;
#         height: 200px;
#         background-image:
#             url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='20' height='20'> <rect fill='red' x='0' y='0' width='90%' height='90%'/> </svg>");
#         }
# </style>
# <div class="container">
#     <div class="box">BOX</div>
# </div>
# Out:
# <style>
#     .box {
#         width: 600px;
#         height: 200px;
#         background-image:
#             url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='20' height='20'> <rect fill='red' x='0' y='0' width='90%' height='90%'/> </svg>");
#         }
# </style>
# <div class="container">
#     <div class="box">BOX</div>
# </div>

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="inline-monaural-sound-logomark"
#     x="0px" y="0px" width="155px" height="155px" viewBox="0 0 155 155" enable-background="new 0 0 155 155">
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
#     <path id="inline-ms-logomark-mask" fill-rule="evenodd" clip-rule="evenodd" fill="#FFFFFF"
#         d="M142.21,78.07l-8.35-31.14c-1.28-1.4-2.49-2.54-3.63-3.42c-2-1.54-4.85-2.33-8.59-2.33c-4.11,0-7.45,1.02-9.99,3.06c-2.57,2.04-3.82,4.69-3.82,7.89c0,2.79,1,5.24,3.02,7.36c2.03,2.16,5.77,4.17,11.22,6.09c5.42,1.92,9.67,3.87,12.69,5.85C137.79,73.44,140.27,75.65,142.21,78.07z M106.08,84.88v4.59c0,11.6,4.86,17.36,14.62,17.36c4.31,0,7.72-1.54,10.27-4.63c2.33-2.85,3.59-6.7,3.77-11.52c-0.32-1.22-0.8-2.44-1.43-3.67c-1.26-2.45-2.83-4.46-4.71-6.03s-5.22-3.2-9.96-4.86c-3.37-1.16-6.22-2.32-8.53-3.48c-0.92-6.58-3.5-12.08-7.76-16.54c-2.15-2.27-4.58-4.08-7.27-5.44c0.29-5.52,2.7-10.3,7.3-14.28c4.91-4.25,10.84-6.38,17.83-6.38c3.14,0,6.31,0.49,9.51,1.48L128.25,26L57.56,7.06L5.81,58.81l3.9,14.55c1.1-5.18,3.47-9.64,7.08-13.38c5.17-5.35,11.79-8.03,19.82-8.03c8.21,0,14.86,2.68,19.93,8.03c0.37,0.39,0.73,0.78,1.08,1.19c0.35-0.41,0.71-0.8,1.09-1.19c5.17-5.35,11.79-8.03,19.82-8.03c8.21,0,14.86,2.68,19.93,8.03c5.1,5.35,7.62,12.31,7.62,20.95V84.88z M100.46,111.97c-4.27-4.48-6.73-10.08-7.42-16.87l-0.2,0.04v-4.12v-6.14v-2.4c0-11.6-4.86-17.36-14.62-17.36c-4.31,0-7.72,1.55-10.27,4.63c-2.52,3.09-3.79,7.34-3.79,12.73V120H50.92V82.48c0-11.6-4.86-17.36-14.62-17.36c-4.31,0-7.72,1.55-10.27,4.63c-2.52,3.09-3.79,7.34-3.79,12.73V120H22.2l2.55,9.5l70.69,18.94l28.64-28.64c-1.19,0.13-2.43,0.2-3.69,0.2C112.18,120,105.53,117.32,100.46,111.97z" />
#     <polygon id="inline-ms-logomark-stroke" fill-rule="evenodd" clip-rule="evenodd" fill="none" stroke="#7D7D7D"
#         stroke-linecap="round" stroke-linejoin="round" stroke-miterlimit="10"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
# </svg>
# <script>
#     var svg_img = document.getElementById('inline-monaural-sound-logomark');
#     svg_img.setAttribute('width', '128');
#     svg_img.setAttribute('height', '128');
#     svg_img.onmouseover = changeHoverColor;
#     svg_img.onmouseout = changeDefaultColor;
#     function changeHoverColor() {
#         document.getElementById('inline-ms-logomark-line').setAttribute('fill', '#FFFFFF');
#         document.getElementById('inline-ms-logomark-mask').setAttribute('fill', '#0CB9C7');
#         document.getElementById('inline-ms-logomark-stroke').setAttribute('stroke', '#0CB9C7');
#     }
#     function changeDefaultColor() {
#         document.getElementById('inline-ms-logomark-line').setAttribute('fill', '#0CB9C7');
#         document.getElementById('inline-ms-logomark-mask').setAttribute('fill', '#FFFFFF');
#         document.getElementById('inline-ms-logomark-stroke').setAttribute('stroke', '#7D7D7D');
#     }
# </script>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="inline-monaural-sound-logomark"
#     x="0px" y="0px" width="155px" height="155px" viewBox="0 0 155 155" enable-background="new 0 0 155 155">
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
#     <path id="inline-ms-logomark-mask" fill-rule="evenodd" clip-rule="evenodd" fill="#FFFFFF"
# ...

# %%
# %%html
# <!-- <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="inline-monaural-sound-logomark"
#     x="0px" y="0px" width="155px" height="155px" viewBox="0 0 155 155" enable-background="new 0 0 155 155">
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
# </svg> -->
# <svg xmlns="http://www.w3.org/2000/svg"
#     width="155px" height="155px" viewBox="0 0 155 155" >
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
# </svg>
# <!-- background-image:
#             url("data:image/svg+xml;utf8, -->
# <svg xmlns='http://www.w3.org/2000/svg' width='20' height='20'>
#     <rect fill='red' x='0' y='0' width='90%' height='90%' />
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg"
#     width="100px" height="100px" viewBox="0 0 1000 1000" >
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
# </svg>
# Out:
# <!-- <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="inline-monaural-sound-logomark"
#     x="0px" y="0px" width="155px" height="155px" viewBox="0 0 155 155" enable-background="new 0 0 155 155">
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
# </svg> -->
# <svg xmlns="http://www.w3.org/2000/svg"
#     width="155px" height="155px" viewBox="0 0 155 155" >
#     <polygon id="inline-ms-logomark-line" fill-rule="evenodd" clip-rule="evenodd" fill="#0CB9C7"
#         points="128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06 " />
# </svg>
# <!-- background-image:
#             url("data:image/svg+xml;utf8, -->
# <svg xmlns='http://www.w3.org/2000/svg' width='20' height='20'>
#     <rect fill='red' x='0' y='0' width='90%' height='90%' />
# </svg>
# <svg xmlns="http://www.w3.org/2000/svg"
# ...

# %%
# %%html
# <style>
#     .box {
#         width: 600px;
#         height: 200px;
#         background-image:
#             url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='50' height='50' viewBox='0 0 200 200'> <polygon id='inline-ms-logomark-line' fill='cornflowerblue' points='128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06' width='90%' height='90%'/> </svg>");
#         }
# </style>
# <div class="container">
#     <div class="box">BOX</div>
# </div>
# Out:
# <style>
#     .box {
#         width: 600px;
#         height: 200px;
#         background-image:
#             url("data:image/svg+xml;utf8,<svg xmlns='http://www.w3.org/2000/svg' width='50' height='50' viewBox='0 0 200 200'> <polygon id='inline-ms-logomark-line' fill='cornflowerblue' points='128.25,26 147.19,96.69 95.44,148.44 24.75,129.5 5.81,58.81 57.56,7.06' width='90%' height='90%'/> </svg>");
#         }
# </style>
# <div class="container">
#     <div class="box">BOX</div>
# </div>

# %%
# %%html
# <!-- 円 -->
# <svg width="600" height="100" viewBox="0 0 600 100">
#     <circle cx="100" cy="50" r="50" fill="red"></circle>
#     <!-- cx=中心のx座標 cy=中心のy座標 r=半径 -->
# </svg>
# <!-- 楕円 -->
# <svg width="600" height="100" viewBox="0 0 600 100">
#     <ellipse cx="100" cy="50" rx="100" ry="50" fill="blue"></ellipse>
#     <!-- cx=中心のx座標 cy=中心のy座標 rx=半径x方向 ry=半径y方向 -->
# </svg>
# <!-- 長方形 -->
# <svg width="600" height="100" viewBox="0 0 600 100">
#     <rect x="50" y="25" width="100" height="50" rx="10" ry="10" fill="green"></rect>
#     <!-- x=始点のx座標 y=始点のy座標 rx=角の丸みx方向 ry=角の丸みy方向 -->
# </svg>
# <!-- 直線 -->
# <svg width="600" height="150" viewBox="0 0 600 150">
#     <line x1="50" y1="0" x2="200" y2="150" stroke="#000"></line>
#     <!-- x1=始点のx座標 y1=始点のy座標 x2=終点のx座標 y2=終点のy座表 -->
# </svg>
# <!-- 折れ線 -->
# <svg width="600" height="150" viewBox="0 0 600 150">
#     <polyline points="50,25 50,75 100,75 100,125 150,125" stroke="#000" fill="none"></polyline>
#     <!-- points=始点のx座標 y座標 次点のx座標 y座標 ～ 終点のx座標 y座標 -->
# </svg>
# <!-- 多角形 -->
# <svg width="600" height="180" viewBox="0 0 600 180">
#     <polygon points="0,50 75,0 150,50 150,150 0,150" fill="yellow"></polygon>
#     <!-- polylineと同様。但し、始点と終点がつながる -->
# </svg>
# <!-- 複雑な形状 -->
# <svg width="600" height="200" viewBox="0 0 600 200">
#     <path d="M25,25 L150,150 C200,200 250,50 50,25 Z"></path>
#     <!-- M=始点のx座標 y座標 L=直線で次点のx座標 y座標 C=曲線で次点、中間2点のx座標 y座標 Z=閉じる -->
# </svg>
# Out:
# <!-- 円 -->
# <svg width="600" height="100" viewBox="0 0 600 100">
#     <circle cx="100" cy="50" r="50" fill="red"></circle>
#     <!-- cx=中心のx座標 cy=中心のy座標 r=半径 -->
# </svg>
# <!-- 楕円 -->
# <svg width="600" height="100" viewBox="0 0 600 100">
#     <ellipse cx="100" cy="50" rx="100" ry="50" fill="blue"></ellipse>
#     <!-- cx=中心のx座標 cy=中心のy座標 rx=半径x方向 ry=半径y方向 -->
# </svg>
# <!-- 長方形 -->
# <svg width="600" height="100" viewBox="0 0 600 100">
#     <rect x="50" y="25" width="100" height="50" rx="10" ry="10" fill="green"></rect>
#     <!-- x=始点のx座標 y=始点のy座標 rx=角の丸みx方向 ry=角の丸みy方向 -->
# </svg>
# <!-- 直線 -->
# <svg width="600" height="150" viewBox="0 0 600 150">
#     <line x1="50" y1="0" x2="200" y2="150" stroke="#000"></line>
#     <!-- x1=始点のx座標 y1=始点のy座標 x2=終点のx座標 y2=終点のy座表 -->
# </svg>
# <!-- 折れ線 -->
# <svg width="600" height="150" viewBox="0 0 600 150">
#     <polyline points="50,25 50,75 100,75 100,125 150,125" stroke="#000" fill="none"></polyline>
# ...

# %%
# %%html
# <style>
#     .container-fluid {
#         width: 600px;
#         height: 200px;
#     }
#     svg {
#         position: absolute;
#         left: 0;
#         background-color: green;
#     }
# </style>
# <div class="container-fluid">
#     <svg xmlns="http://www.w3.org/2000/svg" width="600" height="200" viewBox="0 0 2000 800">
#         <circle cx="1000" cy="400" r="100" style="stroke:white;stroke-width:2px;fill:white" />
#     </svg>
# </div>
# Out:
# <style>
#     .container-fluid {
#         width: 600px;
#         height: 200px;
#     }
#     svg {
#         position: absolute;
#         left: 0;
#         background-color: green;
#     }
# </style>
# <div class="container-fluid">
#     <svg xmlns="http://www.w3.org/2000/svg" width="600" height="200" viewBox="0 0 2000 800">
#         <circle cx="1000" cy="400" r="100" style="stroke:white;stroke-width:2px;fill:white" />
#     </svg>
# </div>

# %%
# %%html
# <style>
#     .container-fluid {
#         width: 300px;
#         height: 300px;
#     }
#
#     object {
#         position: absolute;
#         left: 0;
#         background-color: green;
#     }
# </style>
# <div class="container-fluid">
#     <object
#         data="data:image/svg+xml;charset=utf-8;base64,"
#         type="image/svg+xml" width="300" height="300" viewport="0 0 600 600"></object>
# </div>
# Out:
# <style>
#     .container-fluid {
#         width: 300px;
#         height: 300px;
#     }
#
#     object {
#         position: absolute;
#         left: 0;
#         background-color: green;
#     }
# </style>
# <div class="container-fluid">
#     <object
#         data="data:image/svg+xml;charset=utf-8;base64,"
#         type="image/svg+xml" width="300" height="300" viewport="0 0 600 600"></object>
# </div>

# %% [markdown]
# # BoxySVG を使ってみる

# %% [markdown]
# オンライン SVG エディターに BoxySVG というのがある。  これを使ってみる。
#
# BoxySVG の特徴はエクスポートとかしなくても、描いた画像が同時に SVG として、文字列で見れる。
#
# これを試してみたい。

# %% [markdown]
# 上部にメニューバーがある。
#
# File, Edit, View, Object, Shape, Tools, Panels, Help
#
# 左側にツールがアイコンで縦に並んでいる。
#
# Transform Tool, Edit Tool, Pan Tool, Quad Bezier Tool, Cubic Bezier Tool, Arc Tool, Freehand Tool, Blob Tool, Text Tool, Text Path Tool, View Tool, Rectangle Tool, Circle Tool, Ellipse Tool, Ring Tool, Pie Tool, Crescent Tool, Triangle Tool, N-gon Tool, Star Tool, Cog Tool, Arrow Tool, Cross Tool, Line Tool, Polyline Tool, Poligon Tool。
#
# 右側がパネルバーというのかな、縦にパネルを開くボタン(アイコン)がある。
#
# Fill Panel, Stroke Panel, Compositing Panel, Typography Panel, Geometry Panel, Meta Panel, Shape Panel, Arrangement Panel, Objects Panel, Defs Panel, Library Panel, Gnenerators Panel, Export Panel, History Panel。
#
# 下に一つだけ Elements というボタンがあってこれが、Elements Panel。
#
# メニューの Tools と Panels はそれぞれ Tools と Panels に対応する。
#
# メニューの Files は、New, New from Selected, New from Clipboard, New from URL, Open form Disk, Open form Cloud, Open Recent, Save, Save to Disc as, Save to Cloud as, Import from Disk, Import from URL, Export to Disk, Share, Print, Reload, Close。
#
# メニューの Edit は、Undo: Move, Redo, Cut, Copy, Paste, Duplicate, Delete, Select All, Deselect All, Preferences。
#
# メニューの Object は、Group, Ungroup, Clip, Unclip, Mask, Unmask, Raise, Lower, Rase to Front, Lower to Back, Rotate +90°, Rotate -90°, Flip X, Flip Y, Remove Transform, Reduce Transform。
#
# メニューの Shape は、Grab Paint Color, Reorient, Reverse, Unite, Subtract, Intersect, Exclude, Shape to Path, Stroke to Path, Join Paths, Split Path, Open Path, Close Path, Inset Path, Outset Path, Simplify Path, Complexity Path, Join Nodes, Split Node, Delete Node, Break Node。
#
# メニューの Help は、About, Hopepage, Blog, Tutorials, Ideas, Bugs, Questions。

# %% [markdown]
# 絵を描いて、Elements ボタンを押して出てくる svg テキストに width を加えるだけで、下のように html で表示ができる!!!!

# %%
# %%html
# <svg width="200"  viewBox="77.225 71.335 168.194 148.56" xmlns="http://www.w3.org/2000/svg" xmlns:bx="https://boxy-svg.com">
#   <defs></defs>
#   <path d="M 155.532 103.106 Q 187.792 67.607 200.714 103.106 L 219.429 154.52 Q 232.351 190.019 187.169 190.019 L 121.732 190.019 Q 76.55 190.019 108.81 154.52 Z" style="fill: rgb(216, 216, 216);" bx:shape="triangle 76.55 67.607 155.801 122.412 0.714 0.29 1@5f0d31b2"></path>
# </svg>
# Out:
# <svg width="200"  viewBox="77.225 71.335 168.194 148.56" xmlns="http://www.w3.org/2000/svg" xmlns:bx="https://boxy-svg.com">
#   <defs></defs>
#   <path d="M 155.532 103.106 Q 187.792 67.607 200.714 103.106 L 219.429 154.52 Q 232.351 190.019 187.169 190.019 L 121.732 190.019 Q 76.55 190.019 108.81 154.52 Z" style="fill: rgb(216, 216, 216);" bx:shape="triangle 76.55 67.607 155.801 122.412 0.714 0.29 1@5f0d31b2"></path>
# </svg>

# %%
# %%html
# <svg width="200px" viewBox="110 79.333 79.334 77.334" xmlns="http://www.w3.org/2000/svg">
#   <defs></defs>
#   <circle style="fill: rgb(255, 19, 196);" cx="174.667" cy="138.667" r="48.557"></circle>
# </svg>
# Out:
# <svg width="200px" viewBox="110 79.333 79.334 77.334" xmlns="http://www.w3.org/2000/svg">
#   <defs></defs>
#   <circle style="fill: rgb(255, 19, 196);" cx="174.667" cy="138.667" r="48.557"></circle>
# </svg>

# %% [markdown]
# # いまここ
